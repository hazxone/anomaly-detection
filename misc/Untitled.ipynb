# %%
from scipy import io

# %%
tydata = io.loadmat('thyroid.mat')

# %%
tydata.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
tydata
# Out:
# {'X': array([[  7.74193548e-01,   1.13207547e-03,   1.37571157e-01,
#            2.75700935e-01,   2.95774648e-01,   2.36065574e-01],
#         [  2.47311828e-01,   4.71698113e-04,   2.79886148e-01,
#            3.29439252e-01,   5.35211268e-01,   1.73770492e-01],
#         [  4.94623656e-01,   3.58490566e-03,   2.22960152e-01,
#            2.33644860e-01,   5.25821596e-01,   1.24590164e-01],
#         ...,
#         [  9.35483871e-01,   2.45283019e-02,   1.60341556e-01,
#            2.82710280e-01,   3.75586854e-01,   2.00000000e-01],
#         [  6.77419355e-01,   1.47169811e-03,   1.90702087e-01,
#            2.42990654e-01,   3.23943662e-01,   1.95081967e-01],
#         [  4.83870968e-01,   3.56603774e-03,   1.90702087e-01,
#            2.12616822e-01,   3.38028169e-01,   1.63934426e-01]]),
#  '__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-05 13:11:25 UTC',
#  '__version__': '1.0',
#  'y': array([[ 0.],
#         [ 0.],
# ...

# %%
tydata_X = tydata['X']

# %%
tydata_X.shape
# Out:
# (3772, 6)

# %%
tydata_y = tydata['y']

# %%
import numpy as np
tydata_all = np.hstack((tydata_X, tydata_y))

# %%
import pandas as pd

# %%
df = pd.DataFrame(tydata_all)

# %%
df
# Out:
#              0         1         2         3         4         5    6
# 0     0.774194  0.001132  0.137571  0.275701  0.295775  0.236066  0.0
# 1     0.247312  0.000472  0.279886  0.329439  0.535211  0.173770  0.0
# 2     0.494624  0.003585  0.222960  0.233645  0.525822  0.124590  0.0
# 3     0.677419  0.001698  0.156546  0.175234  0.333333  0.136066  0.0
# 4     0.236559  0.000472  0.241935  0.320093  0.333333  0.247541  0.0
# 5     0.731183  0.000472  0.147059  0.196262  0.239437  0.198361  0.0
# 6     0.903226  0.000472  0.213472  0.294393  0.399061  0.195082  0.0
# 7     0.505376  0.003925  0.185009  0.196262  0.276995  0.177049  0.0
# 8     0.709677  0.002453  0.222960  0.198598  0.422535  0.127869  0.0
# 9     0.806452  0.000189  0.270398  0.285047  0.511737  0.155738  0.0
# 10    0.655914  0.020755  0.071157  0.165888  0.258216  0.157377  0.0
# 11    0.182796  0.000189  0.213472  0.224299  0.309859  0.185246  0.0
# ...

# %%
df.isnull().T.any().T.sum()
# Out:
# 0
